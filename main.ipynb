# %%
import pandas as pd

# %% [markdown]
# ## Análise e tratamento da planilha
# A planilha utilizada foi a [Tabela Brasileira de Composição de Alimentos - 4a edição](https://www.nepa.unicamp.br/taco/tabela.php?ativo=tabela)
#
# Para o escopo do projeto, serão analisados somente os macronutrientes proteína, carboidratos e gorduras (lipídeos); e os micronutrientes vitaminas A e C, minerais cálcio e ferro.
#
# As demais colunas serão removidas.

# %%
df = pd.read_excel('taco3.xls')

# Elimina colunas não usadas
df = df.drop(['Unnamed: 2', 'Unnamed: 7'] 
			 	+ df.columns[9:11].tolist() 
				+ df.columns[12:16].tolist() 
				+ df.columns[17:21].tolist() 
				+ df.columns[22:28].tolist(), axis=1)

# Renomeia colunas
df.columns = ['Número do alimento', 'Descrição dos alimentos', 'Energia (kcal)', 
				'Energia (kJ)', 'Proteína (g)', 'Lipídeos (g)', 
				'Carboidrato (g)', 'Cálcio (mg)', 'Ferro (mg)', 
				'Vitamina A (mcg)', 'Vitamica C (mg)']

# Elimina linhas redundantes e reseta index
df = df.drop(index=[0, 1], axis=0)
df = df.reset_index(drop=True)

df.head()
# Out:
#     Número do alimento  Descrição dos alimentos Energia (kcal) Energia (kJ)
# 0  Cereais e derivados                      NaN            NaN          NaN  \
# 1                    1  Arroz, integral, cozido     123.534893    516.86999
# 2                    2     Arroz, integral, cru     359.678002  1504.892761
# 3                    3    Arroz, tipo 1, cozido     128.258486   536.633504
# 4                    4       Arroz, tipo 1, cru     357.789273  1496.990319
#
#   Proteína (g) Lipídeos (g) Carboidrato (g) Cálcio (mg) Ferro (mg)
# 0          NaN          NaN             NaN         NaN        NaN  \
# 1      2.58825     1.000333        25.80975       5.204      0.262
# 2     7.323286     1.864833       77.450714       7.818   0.948333
# 3     2.520817        0.227        28.05985    3.544333   0.076667
# 4      7.15854        0.335       78.759543    4.414333   0.677747
#
#   Vitamina A (mcg) Vitamica C (mg)
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
